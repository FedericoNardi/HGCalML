# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
with h5py.File("/media/disk/g4_showers/2D/photon_showers_5.h5", "r") as f:
    evt = f['event_1'][()]

# %%
import matplotlib.colors as mcolors
print(evt.shape)
print(evt[:,2].sum()) # (x,z,dE,E0)
dE = evt[:,2].reshape(100,100)
plt.imshow(dE.T, origin='lower', cmap='hot', norm=mcolors.LogNorm())
plt.colorbar()
# Out:
# (10000, 4)
# 146046.27392688178
